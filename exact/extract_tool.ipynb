# %%
from aria_skyline import process_single_file

# %%
import aria_skyline
import argparse

args = argparse.Namespace(
    type='skyline_topk',
    k=1,
    input_dir='/Users/andrewyang/Downloads',
    output_dir='/Users/andrewyang/Downloads/nyan_cat_output'
)

aria_skyline.process_single_file(
    '/Users/andrewyang/Downloads/nyan_cat.mid',
    args
)
# Out:
# '/Users/andrewyang/Downloads/nyan_cat.mid is done. Good job'
